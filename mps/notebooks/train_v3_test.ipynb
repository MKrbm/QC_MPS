# %%
import opt_einsum as oe
import numpy as np
import torch
import sys
sys.path.append("../../")
import mps
from mps.trainer.data_utils import create_mnist_dataloader, SyntheticDataset, SyntheticDatasetV2, SyntheticDatasetV3

# %%
N = 500
dataset = SyntheticDatasetV3(n = N, num_samples=2**15, seed = 0)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=2**12, shuffle=True)

# %%
from mps.trainer.smps_trainer import smps_train
from mps.simple_mps import SimpleMPS
import copy
# smps_params = torch.load("smps_2000.pth", weights_only=False)

chi = 2
d = 2
l = 2
device = torch.device("cpu")
dtype = torch.float64
optimize = "greedy"
eps = 0.1 / np.sqrt(N)
smps = SimpleMPS(N, chi, d, l, layers=1, device=device, dtype=dtype, optimize=optimize, eps=eps)

smps.mps.params[0].data[:] = torch.tensor([ [0, 1], [1, 0] ])
for i in range(1, len(smps.mps.params) - 1):
    smps.mps.params[1].data[:] = torch.stack((torch.eye(2), ) * 2).permute(1, 0, 2)
# Out:
# Path is not set, setting...
# Found the path
# Initialized MPS with random matrices

# %%
from mps.trainer.smps_trainer import smps_train
import copy

epochs = 100
lr = 0.0001
logsoftmax = torch.nn.LogSoftmax(dim=-1)
nnloss = torch.nn.NLLLoss(reduction="mean")
opt_smps = torch.optim.Adam(smps.parameters(), lr=lr)
smps_losses = []
smps.train()
print(f"\n=== Training SimpleMPS for {epochs} epoch(s)... ===")
for epoch in range(epochs):
    total_loss = 0.0
    total_samples = 0
    total_correct = 0
    for batch_idx, (data, target) in enumerate(dataloader):
        data, target = data.to(device), target.to(device)
        data = data.permute(1, 0, 2)  # [batch, N, 2] → [N, batch, 2]
        opt_smps.zero_grad()
        outputs = smps(data)
        outputs = torch.abs(outputs)
        outputs = logsoftmax(outputs)
        loss = nnloss(outputs, target)
        loss.backward()
        
        # Print the norm of the gradients for 10 equally split indices
        params = list(smps.parameters())
        num_params = len(params)
        indices = [int(i * num_params / 10) for i in range(10)]
        grad_norms = [f"Gradient norm for parameter {idx}: {params[idx].grad.norm().item():.6f}" for idx in indices if params[idx].grad is not None]
        print(" | ".join(grad_norms))
        
        opt_smps.step()
        bs = target.size(0)
        total_loss += loss.item() * bs
        total_samples += bs
        preds = outputs.argmax(dim=-1)
        acc = (preds == target).float().sum().item()
        total_correct += acc
        print(f"[SimpleMPS] Epoch {epoch+1}, Step {batch_idx+1}/{len(dataloader)} | Loss: {loss.item():.6f} | Acc: {acc/bs:.2%}")
    epoch_loss = total_loss / total_samples
    epoch_acc = total_correct / total_samples
    smps_losses.append(epoch_loss)
    print(f"[SimpleMPS] Epoch {epoch+1} | Loss: {epoch_loss:.6f} | Acc: {epoch_acc:.2%}")
# Out:
# === Training SimpleMPS for 100 epoch(s)... ===
# Gradient norm for parameter 0: 0.207978 | Gradient norm for parameter 50: 0.147605 | Gradient norm for parameter 100: 0.149558 | Gradient norm for parameter 150: 0.148548 | Gradient norm for parameter 200: 0.148617 | Gradient norm for parameter 250: 0.148380 | Gradient norm for parameter 300: 0.146997 | Gradient norm for parameter 350: 0.147084 | Gradient norm for parameter 400: 0.146351 | Gradient norm for parameter 450: 0.145260
# [SimpleMPS] Epoch 1, Step 1/8 | Loss: 0.308958 | Acc: 100.00%
# Gradient norm for parameter 0: 0.192746 | Gradient norm for parameter 50: 0.136878 | Gradient norm for parameter 100: 0.136427 | Gradient norm for parameter 150: 0.136067 | Gradient norm for parameter 200: 0.135964 | Gradient norm for parameter 250: 0.136442 | Gradient norm for parameter 300: 0.136626 | Gradient norm for parameter 350: 0.136084 | Gradient norm for parameter 400: 0.136439 | Gradient norm for parameter 450: 0.136193
# [SimpleMPS] Epoch 1, Step 2/8 | Loss: 0.293680 | Acc: 100.00%
# Gradient norm for parameter 0: 0.206184 | Gradient norm for parameter 50: 0.147095 | Gradient norm for parameter 100: 0.147024 | Gradient norm for parameter 150: 0.146681 | Gradient norm for parameter 200: 0.146502 | Gradient norm for parameter 250: 0.146293 | Gradient norm for parameter 300: 0.145694 | Gradient norm for parameter 350: 0.145553 | Gradient norm for parameter 400: 0.146121 | Gradient norm for parameter 450: 0.144750
# [SimpleMPS] Epoch 1, Step 3/8 | Loss: 0.281346 | Acc: 100.00%
# Gradient norm for parameter 0: 0.206048 | Gradient norm for parameter 50: 0.146447 | Gradient norm for parameter 100: 0.147227 | Gradient norm for parameter 150: 0.146835 | Gradient norm for parameter 200: 0.146670 | Gradient norm for parameter 250: 0.146508 | Gradient norm for parameter 300: 0.145931 | Gradient norm for parameter 350: 0.145694 | Gradient norm for parameter 400: 0.145966 | Gradient norm for parameter 450: 0.144746
# [SimpleMPS] Epoch 1, Step 4/8 | Loss: 0.267083 | Acc: 100.00%
# Gradient norm for parameter 0: 0.202155 | Gradient norm for parameter 50: 0.143741 | Gradient norm for parameter 100: 0.144150 | Gradient norm for parameter 150: 0.143449 | Gradient norm for parameter 200: 0.143156 | Gradient norm for parameter 250: 0.143359 | Gradient norm for parameter 300: 0.143137 | Gradient norm for parameter 350: 0.142681 | Gradient norm for parameter 400: 0.143100 | Gradient norm for parameter 450: 0.142163
# [SimpleMPS] Epoch 1, Step 5/8 | Loss: 0.252019 | Acc: 100.00%
# Gradient norm for parameter 0: 0.195829 | Gradient norm for parameter 50: 0.139233 | Gradient norm for parameter 100: 0.138793 | Gradient norm for parameter 150: 0.138301 | Gradient norm for parameter 200: 0.138139 | Gradient norm for parameter 250: 0.138610 | Gradient norm for parameter 300: 0.138819 | Gradient norm for parameter 350: 0.138227 | Gradient norm for parameter 400: 0.138769 | Gradient norm for parameter 450: 0.138532
# [SimpleMPS] Epoch 1, Step 6/8 | Loss: 0.238250 | Acc: 100.00%
# Gradient norm for parameter 0: 0.197664 | Gradient norm for parameter 50: 0.140256 | Gradient norm for parameter 100: 0.140623 | Gradient norm for parameter 150: 0.140041 | Gradient norm for parameter 200: 0.139795 | Gradient norm for parameter 250: 0.140060 | Gradient norm for parameter 300: 0.140100 | Gradient norm for parameter 350: 0.139493 | Gradient norm for parameter 400: 0.139772 | Gradient norm for parameter 450: 0.139345
# [SimpleMPS] Epoch 1, Step 7/8 | Loss: 0.224224 | Acc: 100.00%
# [SimpleMPS] Epoch 10, Step 3/8 | Loss: 0.000810 | Acc: 100.00%
# Gradient norm for parameter 0: 0.003870 | Gradient norm for parameter 50: 0.002742 | Gradient norm for parameter 100: 0.002750 | Gradient norm for parameter 150: 0.002740 | Gradient norm for parameter 200: 0.002732 | Gradient norm for parameter 250: 0.002743 | Gradient norm for parameter 300: 0.002747 | Gradient norm for parameter 350: 0.002734 | Gradient norm for parameter 400: 0.002744 | Gradient norm for parameter 450: 0.002735
# [SimpleMPS] Epoch 10, Step 4/8 | Loss: 0.000785 | Acc: 100.00%
# Gradient norm for parameter 0: 0.003790 | Gradient norm for parameter 50: 0.002700 | Gradient norm for parameter 100: 0.002701 | Gradient norm for parameter 150: 0.002683 | Gradient norm for parameter 200: 0.002677 | Gradient norm for parameter 250: 0.002685 | Gradient norm for parameter 300: 0.002688 | Gradient norm for parameter 350: 0.002678 | Gradient norm for parameter 400: 0.002696 | Gradient norm for parameter 450: 0.002683
# [SimpleMPS] Epoch 10, Step 5/8 | Loss: 0.000766 | Acc: 100.00%
# Gradient norm for parameter 0: 0.003717 | Gradient norm for parameter 50: 0.002643 | Gradient norm for parameter 100: 0.002642 | Gradient norm for parameter 150: 0.002634 | Gradient norm for parameter 200: 0.002625 | Gradient norm for parameter 250: 0.002635 | Gradient norm for parameter 300: 0.002636 | Gradient norm for parameter 350: 0.002626 | Gradient norm for parameter 400: 0.002635 | Gradient norm for parameter 450: 0.002627
# [SimpleMPS] Epoch 10, Step 6/8 | Loss: 0.000750 | Acc: 100.00%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 20
#      18 data = data.permute(1, 0, 2)  # [batch, N, 2] → [N, batch, 2]
#      19 opt_smps.zero_grad()
# ---> 20 outputs = smps(data)
#      21 outputs = torch.abs(outputs)
#      22 outputs = logsoftmax(outputs)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/presentation/QC_MPS/mps/notebooks/../../mps/simple_mps.py:360, in SimpleMPS.forward(self, X)
#     358     self.ops[self.left_qubit_inds[i]] = X[i]
#     359 # measurement qubits
# --> 360 return torch.abs(oe.contract(self.estr_mps, *self.ops, backend="torch", optimize=self.path))
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/opt_einsum/contract.py:595, in contract(subscripts, out, use_blas, optimize, memory_limit, backend, *operands, **kwargs)
#     593 # Build the contraction list and operand
#     594 contraction_list: ContractionListType
# --> 595 operands, contraction_list = contract_path(  # type: ignore
#     596     *operands_list, optimize=optimize, memory_limit=memory_limit, einsum_call=True, use_blas=use_blas
#     597 )
#     599 # check if performing contraction or just building expression
#     600 if gen_expression:
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/opt_einsum/contract.py:369, in contract_path(subscripts, use_blas, optimize, memory_limit, shapes, *operands, **kwargs)
#     365 for cnum, contract_inds in enumerate(path_tuple):
#     366     # Make sure we remove inds from right to left
#     367     contract_inds = tuple(sorted(contract_inds, reverse=True))
# --> 369     contract_tuple = helpers.find_contraction(contract_inds, input_sets, output_set)
#     370     out_inds, input_sets, idx_removed, idx_contract = contract_tuple
#     372     # Compute cost, scale, and size
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/opt_einsum/helpers.py:97, in find_contraction(positions, input_sets, output_set)
#      95 inputs = (remaining.pop(i) for i in sorted(positions, reverse=True))
#      96 idx_contract = frozenset.union(*inputs)
# ---> 97 idx_remain = output_set.union(*remaining)
#      99 new_result = idx_remain & idx_contract
#     100 idx_removed = idx_contract - new_result
#
# KeyboardInterrupt:

# %%
from mps import tpcp_mps
from mps.trainer.utils import calculate_accuracy, focal_loss, mean_risk
# --- Step 2: Build and Prepare TPCP ---
tpcp = tpcp_mps.MPSTPCP(
    N,
    K=1,
    d=2,
    enable_r=True,
    with_identity=False,
    manifold=tpcp_mps.ManifoldType.EXACT,
)
tpcp.set_canonical_mps(smps)
tpcp.train()

W = torch.ones(tpcp.L, 2, dtype=torch.float64)
W[:, 1] = 0
tpcp.initialize_W(W)
torch.save(tpcp.state_dict(), "pth/v3_500_0.pth")
# tpcp_params = torch.load("pth/v3_500_0.pth")
# tpcp.load_state_dict(tpcp_params)

# %%
import os 

schedule_dict = {
    0: {"w": 0.000, "epoch": 15, "clambda": 30, "lr": 0.0001},
    1: {"w": 0.0004, "epoch": 15, "clambda": 90, "lr": 0.0001},
    2: {"w": 0.0013, "epoch": 15, "clambda": 110, "lr": 0.0002},
    3: {"w": 0.0015, "epoch": 15, "clambda": 110, "lr": 0.0002},
    4: {"w": 0.0017, "epoch": 15, "clambda": 90, "lr": 0.0002},
    5: {"w": 0.005, "epoch": 15, "clambda": 90, "lr": 0.0002},
    6: {"w": 0.006, "epoch": 15, "clambda": 90, "lr": 0.0002},
    7: {"w": 0.007, "epoch": 15, "clambda": 90, "lr": 0.0002},
    8: {"w": 0.008, "epoch": 15, "clambda": 90, "lr": 0.0002},
    9: {"w": 0.009, "epoch": 15, "clambda": 90, "lr": 0.0002},
    10: {"w": 0.1, "epoch": 15, "clambda": 90, "lr": 0.0002},
    11: {"w": 0.6, "epoch": 20, "clambda": 40, "lr": 0.0002},
    12: {"w": 0.7, "epoch": 20, "clambda": 40, "lr": 0.0002},
    13: {"w": 0.8, "epoch": 20, "clambda": 40, "lr": 0.0002},
    14: {"w": 0.9, "epoch": 20, "clambda": 40, "lr": 0.0002},
    15: {"w": 0.91, "epoch": 50, "clambda": 40, "lr": 0.00003},
    16: {"w": 0.92, "epoch": 50, "clambda": 40, "lr": 0.00003},
    17: {"w": 0.93, "epoch": 50, "clambda": 40, "lr": 0.00003},
    18: {"w": 0.94, "epoch": 50, "clambda": 40, "lr": 0.00003},
    19: {"w": 0.95, "epoch": 50, "clambda": 40, "lr": 0.00003},
    20: {"w": 0.96, "epoch": 50, "clambda": 40, "lr": 0.00003},
    21: {"w": 0.97, "epoch": 50, "clambda": 40, "lr": 0.00003},
    22: {"w": 0.98, "epoch": 50, "clambda": 40, "lr": 0.00003},
    23: {"w": 0.99, "epoch": 50, "clambda": 40, "lr": 0.00003},
    24: {"w": 1.0, "epoch": 50, "clambda": 40, "lr": 0.00003},
}

# Define the file path for storing epoch metrics
epoch_metrics_file_path = "csv/tpcp_v3_epoch_metrics_1024_2.csv"
# Define the file path for storing iteration metrics
iter_metrics_file_path = "csv/tpcp_v3_iter_metrics_1024_2.csv"

# Initialize the epoch metrics file with headers if it doesn't exist
if not os.path.exists(epoch_metrics_file_path):
    print("Epoch metrics file does not exist. Creating it.")
    with open(epoch_metrics_file_path, 'w') as f:
        f.write("w_value,epoch,avg_loss,avg_loss_with_reg,avg_acc,avg_srpq,avg_reg\n")

# Initialize the iteration metrics file with headers if it doesn't exist
if not os.path.exists(iter_metrics_file_path):
    print("Iteration metrics file does not exist. Creating it.")
    with open(iter_metrics_file_path, 'w') as f:
        f.write("w_value,epoch,iter,loss0,reg,loss,acc,srpq\n")

# %%
tpcp.W[:,1].max()
# Out:
# tensor(0., dtype=torch.float64, grad_fn=<MaxBackward1>)

# %%
logsoftmax = torch.nn.LogSoftmax(dim=-1)
nnloss = torch.nn.NLLLoss(reduction="mean")

def update_weights_min(W_now, w_min):
    return torch.maximum(W_now, torch.tensor(w_min))

# torch.save(tpcp.state_dict(), "pth/tpcp_state_dict_tmp.pth")
# tpcp_params = torch.load(f"pth/tpcp_state_dict_v3_1024_i_1.pth")
# tpcp.load_state_dict(tpcp_params)
# W = update_weights_min(tpcp.W, 0.0000)
W = torch.ones(tpcp.L, 2, dtype=torch.float64)
W[:, 1] = 0.001
tpcp.initialize_W(W)
# W_now = tpcp.W.clone()
# W_new = update_weights(W_now, 0.01)
# tpcp.initialize_W(W_new)
# torch.save(tpcp.state_dict(), "tpcp_state_dict_new.pth")
# 
# --- Step 3: Determine lambda_final Using the Initial Loss Value ---
data_batch, target_batch = next(iter(dataloader))
initial_probs, reg = tpcp(data_batch, return_probs=True, return_reg=True)
initial_accuracy = calculate_accuracy(initial_probs[:, 0], target_batch)
srpq = torch.exp(-reg)
sr_sys = torch.exp(-reg*N)
print("srpq: ", srpq)
print("success rate : ", sr_sys)
print(f"Initial accuracy: {initial_accuracy.item():.2%}")
loss = focal_loss(initial_probs, target_batch, gamma=0.0, alpha = 0.5)
# ls = logsoftmax(initial_probs)
# loss = nnloss(ls, target_batch)
print(f"Initial loss: {loss.item()}")
# Out:
# srpq:  tensor(0.5005, dtype=torch.float64, grad_fn=<ExpBackward0>)
# success rate :  tensor(4.9960e-151, dtype=torch.float64, grad_fn=<ExpBackward0>)
# Initial accuracy: 100.00%
# Initial loss: 0.11056215701375577

# %%
from mps.trainer.adaptive_mpsae_trainer import RiemannianAdam
from geoopt import optim
from mps.StiefelOptimizers import StiefelAdam, StiefelSGD
import torch
import pandas as pd
import os

# Predefined schedule for W[:, 1]


# tpcp_params = torch.load("pth/v3_500_0.pth")
# tpcp.load_state_dict(tpcp_params)

i = 1
# clambda = schedule_dict[i]["clambda"]
# w_value = schedule_dict[i]["w"]
# lr = schedule_dict[i]["lr"]
# epochs = schedule_dict[i]["epoch"]
clambda = 90
w_value = 0.0004
lr = 0.001
epochs = 15

print(f"Training TPCP with w_value: {w_value}, epochs: {epochs}, lr: {lr}, clambda: {clambda}")
W = torch.zeros(tpcp.L, 2, dtype=torch.float64)

torch.save(tpcp.state_dict(), f"pth/v3_500_i_{i}.pth")

W = torch.ones(tpcp.L, 2, dtype=torch.float64)
W[:, 1] = w_value
tpcp.initialize_W(W)
# 
optimizer = optim.RiemannianSGD(tpcp.kraus_ops.parameters(), lr=lr)
optimizer_weight = torch.optim.Adam([tpcp.r, tpcp.W], lr=lr * 0.1)
tpcp.W.requires_grad = True
tpcp.r.requires_grad = True


for epoch in range(epochs):
    epoch_loss_sum = 0.0
    epoch_acc_sum = 0.0
    epoch_loss_with_reg_sum = 0.0
    epoch_srpq_sum = 0.0
    epoch_reg_sum = 0.0
    epoch_w = 0.0
    total_samples = 0

    for iter_num, (data, target) in enumerate(dataloader, start=1):
        optimizer.zero_grad()
        optimizer_weight.zero_grad()
        outputs, reg = tpcp(data, return_probs=True, return_reg=True)
        loss0 = focal_loss(outputs, target, gamma=0.0, alpha = 0.5)
        risk = mean_risk(outputs, target)
        # ls = logsoftmax(outputs)
        # loss0 = nnloss(ls, target)
        loss = loss0 + clambda * reg

        loss.backward()

        optimizer.step()
        optimizer_weight.step()

        tpcp.proj_stiefel(check_on_manifold=True, print_log=False, rtol=1e-3)
        tpcp.normalize_w_and_r()

        acc = calculate_accuracy(outputs[:, 0], target)
        srpq = torch.exp(-reg)

        bs = target.size(0)
        epoch_loss_sum += loss0.item() * bs
        epoch_loss_with_reg_sum += loss.item() * bs
        total_samples += bs
        epoch_acc_sum += acc.item() * bs
        epoch_srpq_sum += srpq.item() * bs
        epoch_reg_sum += reg.item() * bs
        epoch_w += tpcp.W.data[:, 1].mean().item() * bs
        # Log iteration metrics
        print(f"Epoch {epoch+1}, Iter {iter_num}, Loss0: {loss0.item():.6f}, reg: {reg.item():.6f}, Loss: {loss.item():.6f}, Acc: {acc.item():.2%}, SRPQ: {srpq.item():.6e}, Risk: {risk.item():.6f}, W: {tpcp.W.data[:, 1].mean().item():.6f}")

        # Write iteration metrics to file
        with open(iter_metrics_file_path, 'a') as f:
            f.write(f"{w_value},{epoch+1},{iter_num},{loss0.item():.6f},{reg.item():.6f},{loss.item():.6f},{acc.item():.6f},{srpq.item():.6e}\n")

    # End of epoch: compute averages.
    avg_loss = epoch_loss_sum / total_samples
    avg_loss_with_reg = epoch_loss_with_reg_sum / total_samples
    avg_acc = epoch_acc_sum / total_samples
    avg_srpq = epoch_srpq_sum / total_samples
    avg_reg = epoch_reg_sum / total_samples
    avg_w = epoch_w / total_samples

    # Log epoch metrics
    print(f"Epoch {epoch+1} Summary | Avg Loss: {avg_loss:.6f} | Avg Loss+Reg: {avg_loss_with_reg:.6f} | Acc: {avg_acc:.2%} | SRPQ: {avg_srpq:.6f} | Reg: {avg_reg:.6f} | W: {avg_w:.6f}")


    # Write epoch metrics to file
    with open(epoch_metrics_file_path, 'a') as f:
        f.write(f"{w_value},{epoch+1},{avg_loss:.6f},{avg_loss_with_reg:.6f},{avg_acc:.6f},{avg_srpq:.6f},{avg_reg:.6f},{avg_w:.6f}\n")
    
    W_now = tpcp.W.clone()
    torch.save(tpcp.state_dict(), f"pth/tpcp_state_dict_v3_1024_i_{i}.pth")
# Out:
# Training TPCP with w_value: 0.0004, epochs: 15, lr: 0.001, clambda: 90
# Epoch 1, Iter 1, Loss0: 0.048544, reg: 0.692766, Loss: 62.397478, Acc: 100.00%, SRPQ: 5.001907e-01, Risk: 0.092463, W: 0.000302
# Epoch 1, Iter 2, Loss0: 0.037425, reg: 0.692863, Loss: 62.395115, Acc: 100.00%, SRPQ: 5.001420e-01, Risk: 0.072079, W: 0.000205
# Epoch 1, Iter 3, Loss0: 0.025952, reg: 0.692960, Loss: 62.392377, Acc: 100.00%, SRPQ: 5.000935e-01, Risk: 0.050558, W: 0.000106
# Epoch 1, Iter 4, Loss0: 0.014129, reg: 0.693055, Loss: 62.389105, Acc: 100.00%, SRPQ: 5.000459e-01, Risk: 0.027851, W: 0.000009
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 58
#      54 # ls = logsoftmax(outputs)
#      55 # loss0 = nnloss(ls, target)
#      56 loss = loss0 + clambda * reg
# ---> 58 loss.backward()
#      60 optimizer.step()
#      61 optimizer_weight.step()
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("iter_metrics.csv")

# %%
df
# Out:
#       epoch  iter     loss0       reg      loss       acc      srpq
# 0         1     1  0.024545  0.693048  6.955023  1.000000  0.500050
# 1         1     2  0.595348  0.693149  7.526838  0.000000  0.499999
# 2         1     3  0.047004  0.693080  6.977806  1.000000  0.500034
# 3         1     4  0.109947  0.693104  7.040985  1.000000  0.500022
# 4         1     5  0.355163  0.693071  7.285869  0.480469  0.500038
# ...     ...   ...       ...       ...       ...       ...       ...
# 1065      2    13  0.000022  0.000003  0.000299  1.000000  0.999997
# 1066      2    14  0.000014  0.000003  0.000270  1.000000  0.999997
# 1067      2    15  0.000013  0.000002  0.000151  1.000000  0.999999
# 1068      2    16  0.000014  0.000001  0.000120  1.000000  0.999999
# 1069      2    17  0.000012  0.000002  0.000208  1.000000  0.999998
#
# [1070 rows x 7 columns]

# %%
df.plot(y = "srpq", logy=True)
# Out:
# <Axes: >

# %%
i = 1
x = data_batch[i]
num_K = tpcp.K

rho0 = torch.einsum("i, j->ij", x[0], x[0].conj())
rho1 = torch.einsum("i, j->ij", x[1], x[1].conj())
rho_in = torch.einsum("ij,kl->ikjl", rho0, rho1).reshape(4, 4)
K = tpcp.kraus_ops[0].data.reshape(num_K, 4, 4)
rho_k_out = torch.einsum("kij, jl, kml->im", K, rho_in, K.conj()).reshape(2, 2, 2, 2)
#partial trace
rho_k_out = torch.einsum("ijil -> jl", rho_k_out)

for k in range(1, len(tpcp.kraus_ops.kraus_ops)):
    K = tpcp.kraus_ops[k].data.reshape(num_K, 4, 4)
    rho_new = torch.einsum("i, j->ij", x[k+1], x[k+1].conj())
    rho_k_in = torch.einsum("ij,kl->ikjl", rho_k_out, rho_new).reshape(4, 4)
    rho_k_out = torch.einsum("kij, jl, kml->im", K, rho_k_in, K.conj()).reshape(2, 2, 2, 2)
    rho_last = rho_k_out.data.reshape(4, 4)
    #partial trace
    rho_k_out = torch.einsum("ijil -> jl", rho_k_out)

mes0 = tpcp.r.conj() @ tpcp.pros0 @ tpcp.r.T - tpcp.r.conj() @ tpcp.pros1 @ tpcp.r.T

print(torch.trace(mes0 @ rho_k_out), target_batch[i])
print(tpcp(data_batch[i].unsqueeze(0)), target_batch[i])
# Out:
# tensor(-0.4681, dtype=torch.float64, grad_fn=<TraceBackward0>) tensor(1)
# tensor([0.0036], dtype=torch.float64, grad_fn=<SelectBackward0>) tensor(1)

# %%
tpcp(data_batch[i].unsqueeze(0)), target_batch[i]
# Out:
# (tensor([0.9907], dtype=torch.float64, grad_fn=<SelectBackward0>), tensor(0))

# %%
MPS_list[0].shape
# Out:
# (2, 4)

# %%
d = smps.mps.d
chi = smps.mps.chi_max
MPS_list = [core.detach().cpu().numpy() for core in smps.mps.params]
MPS_list[0] = MPS_list[0].reshape(1, d, chi)
d = smps.mps.d


new_MPS_list = [np.zeros(mps_shape.shape) for mps_shape in MPS_list]

A = np.copy(MPS_list[0])

for i in range(len(MPS_list) - 1):

    shapeA = A.shape
    A = A.reshape(A.shape[0] * d, -1)
    
    # Perform SVD
    U, S, V = np.linalg.svd(A, full_matrices=False)

    S = S / np.linalg.norm(S)

    S[4:] = 0 
    U[:, 4:] = 0
    
    # Update chi and R
    chi = len(S)
    R = np.diag(S) @ V[:chi]

    if i < len(MPS_list) - 2:
        A = np.copy(MPS_list[i+1])
        A = np.einsum("ij, jdk->idk", R, A)

    # new_MPS_list.append(U.reshape(shapeA[0], shapeA[1], -1))

    At = U.reshape(shapeA[0], shapeA[1], -1)
    Atshape = At.shape
    new_MPS_list[i][:Atshape[0], :Atshape[1], :Atshape[2]] = At

Af = np.copy(MPS_list[-1])
Af = R @ Af
new_MPS_list[-1][:] = Af

new_MPS_list[0] = new_MPS_list[0].reshape(d, smps.mps.chi_max)
new_MPS_list_tensor = [torch.tensor(new_MPS_list[i]) for i in range(len(new_MPS_list))]

# smps.mps.set_params(new_MPS_list_tensor)
# smps.initialize_MPS()

# %%
params = smps.mps.params

chi = 2
smps_new = SimpleMPS(N, chi, d, l, layers=1, device=device, dtype=dtype, optimize=optimize, eps=eps)

params_new = [torch.empty(shape) for shape in smps_new.mps.mps_shapes]

smps.convert_to_canonical()
# Out:
# Path is not set, setting...
# Found the path
# Initialized MPS with random matrices
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 8
#       4 smps_new = SimpleMPS(N, chi, d, l, layers=1, device=device, dtype=dtype, optimize=optimize, eps=eps)
#       6 params_new = [torch.empty(shape) for shape in smps_new.mps.mps_shapes]
# ----> 8 smps.convert_to_canonical()
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/torch/nn/modules/module.py:1928, in Module.__getattr__(self, name)
#    1926     if name in modules:
#    1927         return modules[name]
# -> 1928 raise AttributeError(
#    1929     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1930 )
#
# AttributeError: 'SimpleMPS' object has no attribute 'convert_to_canonical'

# %%
smps_params = torch.load("smps.pth", weights_only=False)

chi = 4
d = 2
l = 2
device = torch.device("cpu")
dtype = torch.float64
optimize = "greedy"
eps = 1e-2
smps = SimpleMPS(N, chi, d, l, layers=1, device=device, dtype=dtype, optimize=optimize, eps=eps)

smps.mps.set_params(smps_params)
smps.initialize_MPS()

d = smps.mps.d
chi = smps.mps.chi_max
MPS_list = [core.detach().cpu().numpy() for core in smps.mps.params]
MPS_list[0] = MPS_list[0].reshape(1, d, chi)
d = smps.mps.d


new_MPS_list = [np.zeros(mps_shape.shape) for mps_shape in MPS_list]

A = np.copy(MPS_list[0])

for i in range(len(MPS_list) - 1):

    shapeA = A.shape
    A = A.reshape(A.shape[0] * d, -1)
    
    # Perform SVD
    U, S, V = np.linalg.svd(A, full_matrices=False)

    U[:, 2:] = 0
    S[2:] = 0
    V[2:, :] = 0
    S = S / np.linalg.norm(S)

    
    # Update chi and R
    chi = len(S)
    R = np.diag(S) @ V[:chi]

    if i < len(MPS_list) - 2:
        A = np.copy(MPS_list[i+1])
        A = np.einsum("ij, jdk->idk", R, A)

    # new_MPS_list.append(U.reshape(shapeA[0], shapeA[1], -1))

    At = U.reshape(shapeA[0], shapeA[1], -1)
    Atshape = At.shape
    new_MPS_list[i][:Atshape[0], :Atshape[1], :Atshape[2]] = At

Af = np.copy(MPS_list[-1])
Af = R @ Af
new_MPS_list[-1][:] = Af

new_MPS_list[0] = new_MPS_list[0].reshape(d, smps.mps.chi_max)
new_MPS_list_tensor = [torch.tensor(new_MPS_list[i]) for i in range(len(new_MPS_list))]

smps.mps.set_params(new_MPS_list_tensor)
smps.initialize_MPS()
# Out:
# Path is not set, setting...
# Found the path
# Initialized MPS with random matrices
# Initialized MPS with random matrices
# Initialized MPS with random matrices

# %%
new_MPS_list[8][:2, :, :2]
# Out:
# array([[[-6.96452678e-01,  6.11388782e-03],
#         [-7.17602633e-01, -6.20796586e-03]],
#
#        [[ 3.50330523e-04, -7.09033352e-01],
#         [-7.31461955e-05, -7.05121115e-01]]])

# %%
# Try to normalize the MPS
# FIrst prepare the test state
x = torch.randn(N, 2, dtype=smps.mps.dtype, device=smps.mps.device)
# x[:, 0] = 1
x = torch.abs(x)
x = x / x.sum(dim=1).unsqueeze(1)

out = smps(x.reshape(N, 1, 2))
sys_scale = torch.abs(out).sum()
s = sys_scale ** (1 / N)

print(sys_scale)

params = smps.mps.params
params_t = [p.detach().cpu() for p in params]
for i in range(len(params)):
   params_t[i] = params_t[i] * (1 / s)# 

smps.mps.set_params(params_t)
smps.initialize_MPS()

# Check the scale again
out = smps(x.reshape(N, 1, 2))
sys_scale = torch.abs(out).sum()

sys_scale
# Out:
# tensor(7.7383e-77, dtype=torch.float64, grad_fn=<SumBackward0>)
# Initialized MPS with random matrices
# tensor(1.4198, dtype=torch.float64, grad_fn=<SumBackward0>)

# %%
smps(data)
# Out:
# tensor([[0.9485, 1.5121],
#         [0.6512, 0.1270],
#         [0.9966, 1.5054],
#         ...,
#         [1.4029, 1.7655],
#         [0.6907, 0.2395],
#         [0.9409, 1.4726]], dtype=torch.float64, grad_fn=<AbsBackward0>)

# %%
1e-78 ** (1 / N)
# Out:
# 0.6982324040771714

# %%
smps(data)
# Out:
# tensor([[0.5329, 0.9569],
#         [0.3981, 0.0426],
#         [0.5706, 0.9784],
#         ...,
#         [0.8310, 1.1142],
#         [0.4377, 0.0711],
#         [0.5476, 0.9555]], dtype=torch.float64, grad_fn=<AbsBackward0>)
