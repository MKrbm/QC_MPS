# %%
import numpy as np

# %%
eps = 0.0001
N = 2
L = 1000
seed = 2024
np.random.seed(seed)
x = np.array([1, 0])
for _ in range(L):
    A = np.eye(N) + eps * np.random.normal(N,N)
    x = x @ A
    x = x / np.sum(x)

y = np.array([0, 1])
for _ in range(L):
    A = np.eye(N) + eps * np.random.normal(N,N)
    y = y @ A
    y = y / np.sum(y)

print(x, y)
# Out:
# [0.83201356 0.16798644] [0.16044187 0.83955813]

# %%
import opt_einsum as oe
import numpy as np
import torch
import sys
sys.path.append("../../")
from mps import simple_mps

# %%
L = 3000
smps = simple_mps.SimpleMPS(N = L, chi = 2, d = 3, l = 3, layers = 1, eps = 0.0001)
# Out:
# Path is not set, setting...
# Found the path
# Initialized MPS with random matrices

# %%
x = smps.mps.params[-1][:, 0]
for i in range(len(smps.mps.params) - 2):
    A = smps.mps.params[-i - 2][:, 0, :]
    x = torch.einsum("ij, j->i",A, x)
    x = x/torch.sum(x)
print(x)
x = smps.mps.params[-1][:, 1]
for i in range(len(smps.mps.params) - 2):
    A = smps.mps.params[-i - 2][:, 0, :]
    x = torch.einsum("ij, j->i",A, x)
    x = x/torch.sum(x)
print(x)
# Out:
# tensor([0.9983, 0.0017], dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor([0.9982, 0.0018], dtype=torch.float64, grad_fn=<DivBackward0>)
