# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
data = pd.read_csv('random_generated_plot.csv')

# Plot the data
plt.plot(data['x'], data['y'])
plt.title('Randomly Generated Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()
